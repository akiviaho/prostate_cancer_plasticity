# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import ranksums, wilcoxon ,spearmanr, pearsonr, kruskal, zscore, fisher_exact, ttest_ind, mannwhitneyu
from matplotlib import pyplot as plt
from tqdm import tqdm
from sklearn.decomposition import PCA

from scipy.cluster.hierarchy import fcluster

from itertools import combinations
from statsmodels.stats.multitest import multipletests

import statsmodels.api as sm

import gseapy as gp

import os
os.chdir('/scratch/svc_td_compbio/users/kiviaho/hillock_club_senescence')

# Load gene modules
gene_modules = pd.read_excel('/home/ak431480/prostate_lineage_signatures.xlsx',skiprows=1)
gene_modules = gene_modules.drop(columns='Housekeeping')

gene_modules_regulons = pd.read_excel('/home/ak431480/grn_regulons_from_lyu_2024_scs_data_20260122.xlsx',index_col=0)
gene_modules_regulons.columns = gene_modules_regulons.columns + ' regulon'
gene_modules = pd.concat([gene_modules,gene_modules_regulons],axis=1)
gene_modules_dict = gene_modules.to_dict('list')
for k in gene_modules_dict:
    gene_modules_dict[k] = [g for g in gene_modules_dict[k] if str(g) != 'nan']

gene_signature_names = list(gene_modules_dict.keys())

### NOTE #### 
# Add nfkb opitmized signatures
sig_df = pd.read_csv('/home/ak431480/nfkb_greedy_optimized_signatures.csv')
# assumes sig_df has columns: signature_name, genes_joined
nfkb_signatures_dict = {
    row["signature_name"]: row["genes_joined"].split(";")
    for _, row in sig_df.iterrows()
}

gene_modules_dict = {**gene_modules_dict, **nfkb_signatures_dict}

def extract_gene_mapping(gtf_file, mapping_type='ENSG'):
    gene_mapping = {}

    with open(gtf_file, 'r') as file:
        for line in file:
            if line.startswith('#'):
                continue
            columns = line.strip().split('\t')
            if columns[2] == 'gene':
                attributes = columns[8].split('; ')
                gene_id = None
                gene_name = None
                for attribute in attributes:
                    if mapping_type == 'ENSG' and attribute.startswith('gene_id'):
                        gene_id = attribute.split(' ')[1].strip('"')
                    elif mapping_type == 'NCBI' and attribute.startswith('gene_id'):
                        gene_id = attribute.split(' ')[1].strip('"')
                    elif attribute.startswith('gene_name'):
                        gene_name = attribute.split(' ')[1].strip('"')
                if gene_id and gene_name:
                    gene_mapping[gene_id] = gene_name

    return pd.DataFrame(list(gene_mapping.items()), columns=['gene_id', 'gene_name'])

# Example usage:
# df = extract_gene_mapping('your_gtf_file.gtf', mapping_type='NCBI')

def extract_gene_lengths_from_gtf(file_path):
    gene_lengths = {}

    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('#'):
                continue
            data = line.strip().split('\t')
            if data[2] == 'gene':
                attributes = data[8].split(';')
                gene_name = [x.split('"')[1] for x in attributes if 'gene_name' in x][0]
                start = int(data[3])
                end = int(data[4])
                length = end - start + 1
                gene_lengths[gene_name] = length

    return gene_lengths


# Function to calculate TPM
def calculate_tpm(df,gene_lengths_per_kb):

    # Gene reads per kilobase
    df_rpk = df.divide(gene_lengths_per_kb,axis=0)

    # Total rpk per sample 
    sample_scaling_factor = df_rpk.sum()/1e6

    # TPM
    tpm_df = df_rpk.divide(sample_scaling_factor)

    return tpm_df

def remove_overlaps(data):
    # Convert lists to sets for easier comparison
    sets = {k: set(v) for k, v in data.items()}
    
    # Iterate over each pair of lists
    for key1, set1 in sets.items():
        for key2, set2 in sets.items():
            if key1 != key2:
                # Find the intersection
                intersection = set1 & set2
                if intersection:
                    # Remove intersection from the longer list
                    if len(set1) > len(set2):
                        sets[key1] -= intersection
                    else:
                        sets[key2] -= intersection
    
    # Convert sets back to lists
    return {k: list(v) for k, v in sets.items()}


def regress_out_signature(df, signature):
    # Extract the signature column
    signature_scores = df[signature]
    
    # Regress out the signature from each column
    for col in df.columns:
        if col != signature:
            X = sm.add_constant(signature_scores)
            y = df[col]
            model = sm.OLS(y, X).fit()
            df[col] = model.resid

    df = df.drop(columns=signature)
    
    return df

def regress_out_signatures(df, signatures):
    # Create the design matrix with a constant and all signature columns
    X = sm.add_constant(df[signatures])
    
    # Regress out the signatures from each column
    for col in df.columns:
        if col not in signatures:
            y = df[col]
            model = sm.OLS(y, X).fit()
            df[col] = model.resid
    
    # Remove the signature columns from the DataFrame
    df = df.drop(columns=signatures)
    
    return df


plot_save_path = '/scratch/svc_td_compbio/users/kiviaho/hillock_club_senescence/'

# %%
tfs_dict = { 
'Androgen signaling response':[
    "HSF1",
    "ERG",
    "HNF1A",
    "FOXP1",
    "FOXO3",
    "CREB3L4",
    "MAF",
    "SREBF1",
    "CREB3",
    "ELK4",
    "NFIX",
    "HOXB13",
    "HOXA10",
    "MYC",
    "AR",
    "MAZ",
    "NKX3-1",
    "FOXA1",
    "SPDEF"],
'Immune interaction':[
    "SOX10",
    "TBX21",
    "CREM",
    "IKZF1",
    "ETS1",
    "RUNX3",
    "BATF",
    "NR3C1",
    "IRF4",
    "RORA"],
'Neuroendocrine differentiation':[
    "ATF4",
    "MAX",
    "STAT1",
    "ASCL1",
    "SOX2",
    "ETV5",
    "TCF12",
    "EMX2",
    "HOXB7",
    "HAND2",
    "FOXC1",
    "MEF2C",
    "NR2F1",
    "RXRG"],
'NF-κB survival signaling':[
    "BHLHE40",
    "FOSL1",
    "IRF6",
    "ETS2",
    "SOX15",
    "NFKB2",
    "RELB",
    "SPIB",
    "REL",
    "BHLHE41",
    "OVOL1"],
'Stem-like reprogramming':[
    "GATA2",
    "NFIA",
    "SOX4",
    "NFIC",
    "STAT3"],
'AP-1 stress response':[
    "JUND",
    "MAFB",
    "EGR1",
    "KLF4",
    "IRF1",
    "ATF3",
    "MAFF"],
'Epithelial reprogramming':[
    "FOS",
    "JUN",
    "JUNB",
    "SOX9",
    "CEBPB",
    "CEBPD",
    "EHF",
    "KLF5",
    "TGIF1",
    "GATA3",
    "NFE2L2"]
}

# Add the aggregate regulons to df dict
for k in tfs_dict:
    regulons = [r + ' regulon' for r in tfs_dict[k]]
    gene_modules_dict[k] = list(gene_modules_regulons[regulons].unstack().dropna().unique())

# %% [markdown]
# ## ARNEO gene set scores and group comparisons

# %%
run_GSVA = True
# Using the real set of RNA-seq data

rnaseq_data = pd.read_csv('./data/arneo-rnaseq/TR169-arneo-tpm-star-rsem.csv',index_col=0)
metadata = pd.read_csv('./data/arneo-rnaseq/case-metadata.txt',index_col=0,sep='\t')

rnaseq_data = rnaseq_data.drop(columns=['ensembl_gene_id','entrezgene_id']).set_index('hgnc_symbol')

missing_meta = pd.DataFrame({
    'TRT_GROUP':np.repeat('treatment-naive',len(rnaseq_data.columns.difference(metadata.index))),
    'tc': np.nan,
    'tc_method': np.nan,
    }, index = rnaseq_data.columns.difference(metadata.index)
    )

metadata = pd.concat([metadata,missing_meta])

# Create a treatment-naive vs neoadjuvant-treated divide
metadata['TRT_GROUP_SIMPLE'] = pd.Categorical(metadata['TRT_GROUP'].map({'treatment-naive':'treatment-naive','adt':'neoadjuvant-treated','adt_apa':'neoadjuvant-treated'}),categories=['treatment-naive','neoadjuvant-treated'])
metadata['tc'] = metadata['tc'].astype('float')

# ONLY KEEP THE TREATMENT-NAIVE PWB SAMPLES

# Match the ordering
overlap = rnaseq_data.columns.intersection(metadata.index)
rnaseq_data = rnaseq_data[overlap]
metadata = metadata.loc[overlap]

# Match gene names to those in signatures
gene_alias_dict = {
    'ACP3' : 'ACPP',
    'CCN1' : 'CYR61',
    'SHLD2' : 'FAM35A',
    'TENT5C': 'FAM46C',
    'TAFA5' : 'FAM19A5',
    'GET3' : 'ASNA1',
}

rnaseq_data = rnaseq_data.rename(index=gene_alias_dict)

if run_GSVA:
    # Log2 transform
    gsva_res = gp.gsva(data=np.log2(rnaseq_data),gene_sets=gene_modules_dict,outdir=None,min_size=0,max_size=100000)
    gsva_res_df = gsva_res.res2d.pivot(index='Name', columns='Term', values='ES').reset_index(names='Sample Identifier')
    gsva_res_df = gsva_res_df.set_index('Sample Identifier').astype('float')

    gsva_res_df = gsva_res_df.loc[overlap]

    if (gsva_res_df.index == metadata.index).all():
        dat = pd.concat([gsva_res_df,metadata], axis=1)

# Calculate z-scores for more intuitive interpretation
dat[gene_signature_names] = zscore(dat[gene_signature_names])

dat['TRT_GROUP'] = pd.Categorical(dat['TRT_GROUP'],categories=['treatment-naive','adt','adt_apa']).remove_unused_categories()
dat['TRT_GROUP_SIMPLE'] = pd.Categorical(dat['TRT_GROUP'].map({'treatment-naive':'treatment-naive','adt':'neoadjuvant-treated','adt_apa':'neoadjuvant-treated'}),categories=['treatment-naive','neoadjuvant-treated'])

arneo_scoring_data = dat.copy()
# Out:
# /home/ak431480/.local/lib/python3.11/site-packages/pandas/core/internals/blocks.py:395: RuntimeWarning: divide by zero encountered in log2
#   result = func(self.values, **kwargs)
# 2026-05-08 09:20:33,221 [WARNING] Found duplicated gene names, values averaged by gene names!
# 2026-05-08 09:20:33,525 [WARNING] Input gene rankings contains inf values!

# %%
## Add clinical data

arneo_clinical = pd.read_excel('/home/ak431480/ARNEO DATABASE_ONCO_FINAL.xlsx',index_col='PatientNumber')
arneo_clinical.index = arneo_clinical.index.astype(str).str.replace('32','ARN')
arneo_clinical.index = arneo_clinical.index.astype(str).str.replace('ARN0ARN','ARN032')

# Add cell fractions from DWLS deconvolution analysis
arneo_cell_fractions = pd.read_pickle('/home/ak431480/cell_type_proportions_20260223.pkl')
arneo_cell_fractions = arneo_cell_fractions * 100
arneo_cell_fractions.columns = [c + ' pct' for c in arneo_cell_fractions.columns]

arneo_clinical = pd.merge(arneo_clinical,arneo_cell_fractions,left_index=True,right_index=True,how='left')

dat_with_clinical = pd.merge(dat,arneo_clinical,left_index=True,right_index=True,how = 'outer')

dat_with_clinical['ypT stage'] = pd.Categorical(dat_with_clinical['ypT2'].map({1:'ypT2',0:'ypT3/4'}),categories=['ypT2','ypT3/4'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Setup & filtering
# -----------------------------
signatures = arneo_cell_fractions.mean().sort_values(ascending=False).index.tolist()
cat = 'TRT_GROUP'
valid_cat = ['adt', 'adt_apa']

plot_meta = dat_with_clinical.copy()
plot_meta = plot_meta[plot_meta[cat].isin(valid_cat)].copy()
plot_meta[cat] = plot_meta[cat].cat.remove_unused_categories()

samples = plot_meta.index.intersection(arneo_cell_fractions.index)

fractions = arneo_cell_fractions.loc[samples, signatures]
meta = plot_meta.loc[samples]

# normalize to 100%
fractions = fractions.div(fractions.sum(axis=1), axis=0) * 100

# sort samples by decreasing epithelial fraction
sample_order = (
    fractions['Epithelial cell pct']
    .sort_values(ascending=True)
    .index
)

fractions = fractions.loc[sample_order]
meta = meta.loc[sample_order]

# -----------------------------
# Custom biologically meaningful palette
# -----------------------------
celltype_palette = {
    'Epithelial cell pct': '#4C72B0',  # muted royal blue
    'Fibroblast pct':      '#C4A46A',  # soft sand / fibro
    'Endothelial cell pct':'#8172B2',  # muted violet-blue
    'T cell pct':          '#55A868',  # desaturated green
    'B cell pct':          '#DD8452',  # muted orange
    'Myeloid cell pct':    '#C44E52',  # brick red
    'Mast cell pct':       '#8C6D62',  # muted brown
}

# fallback for any unexpected cell types
for ct in signatures:
    celltype_palette.setdefault(ct, 'lightgrey')

group_palette = sns.color_palette('Set2')
group_palette = dict(
    zip(meta[cat].cat.categories, [group_palette[2], group_palette[1]])
)

sns.set_theme(
    style='white',
    font_scale=0.55,
    rc={'xtick.bottom': True, 'ytick.left': True}
)

# -----------------------------
# Plot (HORIZONTAL stacked bars)
# -----------------------------
fig, ax = plt.subplots(figsize=(5, 9))

left = np.zeros(len(sample_order))

for cell_type in signatures:
    ax.barh(
        sample_order,
        fractions[cell_type],
        left=left,
        color=celltype_palette[cell_type],
        edgecolor='none',
        label=cell_type
    )
    left += fractions[cell_type].values

# -----------------------------
# Axis styling
# -----------------------------
ax.set_xlabel('Cell type fraction (%)')
ax.set_xlim(0, 100)

ax.spines[['top', 'right']].set_visible(False)
ax.grid(axis='x', linewidth=0.3)

# color y-axis labels by TRT_GROUP
ax.set_yticks(range(len(sample_order)))
ax.set_yticklabels(sample_order, fontsize=6)

for tick, sample in zip(ax.get_yticklabels(), sample_order):
    tick.set_color(group_palette[meta.loc[sample, cat]])
    tick.set_weight('bold')

# -----------------------------
# Legend
# -----------------------------
ax.legend(
    bbox_to_anchor=(1.02, 0.8),
    loc='upper left',
    frameon=False,
    title='Cell type'
)

plt.tight_layout()
plt.savefig('/home/ak431480/notebooks/figures/arneo_stacked_cell_fractions_horizontal.pdf')
plt.show()

# %% [markdown]
# ### Cell type fractions in ADT vs ADT+APA

# %%
signatures = arneo_cell_fractions.mean().sort_values(ascending=False).index.tolist()
cat = 'TRT_GROUP'


valid_cat = ['adt','adt_apa'] 
plot_data = dat_with_clinical.copy()
plot_data = plot_data[plot_data['TRT_GROUP'].isin(valid_cat)].copy()
plot_data['TRT_GROUP'] = plot_data['TRT_GROUP'].cat.remove_unused_categories()


pal = sns.color_palette('Set2')
pal = sns.color_palette([pal[2], pal[1]])
sns.set_theme(style='white', palette=pal, font_scale=0.55, rc={
    'xtick.bottom': True,
    'ytick.left': True
})


#num_modules = len(modules)
num_cols = 4
num_rows = int(np.ceil(len(signatures) / num_cols))

fig, axs = plt.subplots(num_rows, num_cols, figsize=(num_cols * 1.5, num_rows * 3))

for idx, signature in enumerate(signatures):
    row = idx // num_cols
    col = idx % num_cols
    ax = axs[row, col]

    sns.boxplot(data=plot_data, x=cat, y=signature,color='whitesmoke', fliersize=0, ax=ax)
    sns.stripplot(data=plot_data, x=cat, y=signature, hue='TRT_GROUP', s=4, edgecolor='black', linewidth=0.5, legend=False, ax=ax)


    # Mann-Whitney U pairwise comparisons
    group_names = plot_data[cat].unique()
    mw_pvals = []
    for g1, g2 in combinations(group_names, 2):
        data1 = plot_data[plot_data[cat] == g1][signature].dropna()
        data2 = plot_data[plot_data[cat] == g2][signature].dropna()
        if len(data1) > 0 and len(data2) > 0:
            _, mw_pval = mannwhitneyu(data1, data2, alternative='two-sided')
            mw_pvals.append(f"{mw_pval:.4f}")

    #ax.set_xlabel('')
    ax.spines[['top','right']].set_visible(False)
    ax.set_ylim(plot_data[signature].max()*-0.1, plot_data[signature].max() * 1.1)

    mw_text = "\n".join(mw_pvals)
    ax.set_title(f'{signature}\n p = {mw_text}', fontsize=6)
    ax.set_ylabel('Deconvoluted cell type fraction (%)')
    ax.set_xticks(group_names)
    #ax.set_xticklabels(['naïve', 'ADT', 'ADT+APA'])

    ax.grid(axis='y')
axs[1,3].set_visible(False)
plt.tight_layout()
plt.savefig('/home/ak431480/notebooks/figures/arneo_boxplot.pdf')
plt.show()

# %%
arneo_cell_fractions.describe().T.sort_values('mean',ascending=False).round(1)
# Out:
#                       count  mean   std   min   25%   50%   75%   max
# Epithelial cell pct    88.0  46.6  21.0  -0.0  32.0  47.7  64.3  87.2
# Fibroblast pct         88.0  38.5  16.4  10.6  25.1  36.7  48.8  78.1
# Myeloid cell pct       88.0   5.2   7.4   0.0   2.6   4.0   5.9  67.4
# Endothelial cell pct   88.0   4.6   3.5  -0.0   2.5   4.3   5.9  21.1
# B cell pct             88.0   3.9   5.3  -0.0   0.0   1.8   5.6  22.6
# Mast cell pct          88.0   1.2   1.0  -0.0   0.5   0.9   1.7   4.2
# T cell pct             88.0   0.1   0.4  -0.0  -0.0   0.0   0.0   2.1

# %%
from scipy.stats import spearmanr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

signatures = arneo_cell_fractions.mean().sort_values(ascending=False).index.tolist()
cat = 'TRT_GROUP'
yvar = 'RCB_ml'

valid_cat = ['adt', 'adt_apa']
plot_data = dat_with_clinical.copy()
plot_data = plot_data[plot_data[cat].isin(valid_cat)].copy()
plot_data[cat] = plot_data[cat].cat.remove_unused_categories()

# fixed palette (lock colors to groups)
pal = sns.color_palette('Set2')
pal = sns.color_palette([pal[2], pal[1]])
palette = dict(zip(plot_data[cat].cat.categories, pal))

sns.set_theme(
    style='white',
    palette=pal,
    font_scale=0.55,
    rc={'xtick.bottom': True, 'ytick.left': True}
)

num_cols = 4
num_rows = int(np.ceil(len(signatures) / num_cols))

fig, axs = plt.subplots(
    num_rows,
    num_cols,
    figsize=(num_cols * 2.2, num_rows * 2.5),
    squeeze=False
)

ymin, ymax = -2, 21

for idx, signature in enumerate(signatures):
    row = idx // num_cols
    col = idx % num_cols
    ax = axs[row, col]

    df = plot_data[[signature, yvar, cat]].dropna()

    inliers = df[df[yvar] <= ymax]
    outliers = df[df[yvar] > ymax]

    # inliers
    sns.scatterplot(
        data=inliers,
        x=signature,
        y=yvar,
        hue=cat,
        palette=palette,
        s=20,
        edgecolor='black',
        linewidth=0.4,
        legend=False,
        ax=ax
    )

    # outliers (clipped)
    if not outliers.empty:
        sns.scatterplot(
            data=outliers,
            x=signature,
            y=[ymax-0.6],
            hue=cat,
            palette=palette,
            marker='^',
            s=40,
            edgecolor='black',
            linewidth=0.5,
            legend=False,
            ax=ax
        )

    # regression line (fit on full data)
    if len(df) >= 3:
        sns.regplot(
            data=df,
            x=signature,
            y=yvar,
            scatter=False,
            #ci=None,
            color='black',
            order = 1,
            line_kws={'linewidth': 1},
            ax=ax
        )

        r, p = spearmanr(df[signature], df[yvar])
        title = f"{signature}\nSpearman r = {r:.2f}, p = {p:.3f}"
    else:
        title = f"{signature}\nSpearman r = NA"

    ax.set_title(title, fontsize=7)
    ax.set_ylim(ymin, ymax)
    ax.set_yticks([0,5,10,15,20])

    # annotate clipped values
    if not outliers.empty:
        ax.text(
            0.98, 0.98,
            f"{len(outliers)} outlier RCB = {outliers['RCB_ml'].iloc[0]}",
            transform=ax.transAxes,
            ha='right',
            va='top',
            fontsize=6
        )

    ax.spines[['top', 'right']].set_visible(False)
    ax.grid(True, axis='both', linewidth=0.3)
    ax.set_xlabel('Deconvoluted cell type fraction (%)')
    ax.set_ylabel('RCB (ml)')

# hide unused axes
for i in range(len(signatures), num_rows * num_cols):
    axs[i // num_cols, i % num_cols].set_visible(False)

plt.tight_layout()
plt.savefig('/home/ak431480/notebooks/figures/arneo_corrplot.pdf')
plt.show()

# %% [markdown]
# ## Find associations between AR activity and tumor content

# %%
# Filter by treated
#overlap = rnaseq_data.columns.intersection(metadata[metadata['TRT_GROUP'] != 'treatment-naive'].index)
overlap = rnaseq_data.columns.intersection(metadata[metadata['TRT_GROUP'] != 'treatment-naive'].index)

score_names = list(gene_modules_dict.keys())

# Log2 transform
gsva_res = gp.gsva(data=np.log2(rnaseq_data[overlap]),gene_sets=gene_modules_dict,outdir=None,min_size=0,max_size=100000)
gsva_res_df = gsva_res.res2d.pivot(index='Name', columns='Term', values='ES').reset_index(names='Sample Identifier')
gsva_res_df = gsva_res_df.set_index('Sample Identifier').astype('float')

gsva_res_df = gsva_res_df.loc[overlap]

if (gsva_res_df.index == metadata.loc[overlap].index).all():
    dat_treated = pd.concat([gsva_res_df,metadata.loc[overlap]], axis=1)

dat_treated_with_clinical = pd.merge(dat_treated,arneo_clinical,left_index=True,right_index=True)

### CALCULATE REGULON GROUP MEAN SCORE ###
for k in tfs_dict:
    regulons = [r + ' regulon' for r in tfs_dict[k]]
    dat_treated_with_clinical[k] = zscore(dat_treated_with_clinical[regulons].mean(axis=1))

dat_treated_with_clinical[gene_signature_names] = zscore(dat_treated_with_clinical[gene_signature_names])

dat_treated_with_clinical['ypT stage'] = pd.Categorical(dat_treated_with_clinical['ypT2'].map({1:'ypT2',0:'ypT3/4'}),categories=['ypT2','ypT3/4'])


# Add info on ATAC-seq
arneo_atac_samples = pd.read_csv('/home/ak431480/arneo_atac_seq_samples.tsv',sep='\t',header=None).rename(columns={0:'sample'})
dat_treated_with_clinical['has_atac_seq'] = 'no'
dat_treated_with_clinical.loc[dat_treated_with_clinical.index.intersection(arneo_atac_samples['sample']),'has_atac_seq'] = 'yes'


# Add deconvoluted cell type percentages downloaded above
#dat_treated_with_clinical = pd.merge(dat_treated_with_clinical,arneo_cell_fractions,left_index=True,right_index=True,how='left')
# Out:
# /home/ak431480/.local/lib/python3.11/site-packages/pandas/core/internals/blocks.py:395: RuntimeWarning: divide by zero encountered in log2
#   result = func(self.values, **kwargs)
# 2026-05-08 09:24:24,681 [WARNING] Found duplicated gene names, values averaged by gene names!
# 2026-05-08 09:24:24,907 [WARNING] Input gene rankings contains inf values!
# /tmp/ipykernel_427263/434029755.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dat_treated_with_clinical['ypT stage'] = pd.Categorical(dat_treated_with_clinical['ypT2'].map({1:'ypT2',0:'ypT3/4'}),categories=['ypT2','ypT3/4'])
# ...

# %%
pal = sns.color_palette('Set2')
pal = sns.color_palette([pal[2], pal[1]])
sns.set_theme(style='white', palette=pal, font_scale=0.55, rc={
    'xtick.bottom': True,
    'ytick.left': True
})

sig1 = 'Androgen signaling response' # AR
sig2 = 'NF-κB survival signaling' # FOSL1
marker_var = 'BCR_3y'

df_all = dat_treated_with_clinical.copy()

fig, axes = plt.subplots(1, 2, figsize=(5.1, 3), sharey=True, sharex=True)

for ax, tstage in zip(axes, ['ypT2', 'ypT3/4']):
    df = df_all[df_all['ypT stage'] == tstage].copy()

#for ax, tstage in zip(axes, [0, 1]):
#    df = df_all[df_all['BCR_3y'] == tstage].copy()

    df[sig1] = df[sig1].astype('float64')
    df[sig2] = df[sig2].astype('float64')
    df = df[~df[sig1].isna()]

    stat, pval = spearmanr(df[sig1], df[sig2])

    sns.regplot(
        data=df,
        x=sig1,
        y=sig2,
        scatter=False,
        color='black',
        ax=ax
    )

    sns.scatterplot(
        data=df,
        x=sig1,
        y=sig2,
        edgecolor='black',
        linewidth=0.5,
        s=32,
        hue='TRT_GROUP',
        #style = marker_var,
        ax=ax
    )

    ax.spines[['right', 'top']].set_visible(False)
    ax.set_title(
        f'{tstage}\nSpearman r: {stat:.2f}\np-value: {pval:.5f}'
    )

# optional: only show legend once
axes[0].legend_.remove()
axes[1].legend_.remove()
ax.set_xlim(-2.1,2.1)
ax.set_xticks([-2,-1,0,1,2])

plt.tight_layout()
plt.savefig(f'/home/ak431480/notebooks/figures/{sig1}_vs_{sig2}_split_by_ypT_status.pdf')
plt.show()

# %%
import pandas as pd
from scipy.stats import fisher_exact
from statsmodels.stats.multitest import multipletests

sig1 = 'AR regulon'

results = []

for tf in tfs_dict['NF-κB survival signaling']:

    sig2 = tf + ' regulon'

    sig1_thr = df_all[sig1].quantile(0.75)
    sig2_thr = df_all[sig2].quantile(0.75)

    # subset
    df = df_all[df_all['ypT stage'] == 'ypT3/4'].copy()

    # binary top-quartile flags
    df[f'{sig1}_topQ'] = df[sig1] >= sig1_thr
    df[f'{sig2}_topQ'] = df[sig2] >= sig2_thr

    # either sig1 OR sig2
    df['either_topQ'] = df[f'{sig1}_topQ'] | df[f'{sig2}_topQ']

    # contingency table
    crosstab_df = pd.crosstab(df['either_topQ'], df['BCR_3y'])
    crosstab_df = crosstab_df.reindex(index=[True, False], columns=[1,0]).fillna(0)

    # Fisher test
    oddsratio, pval = fisher_exact(crosstab_df)

    results.append({
        'sig1': sig1,
        'sig2': sig2,
        'odds_ratio': oddsratio,
        'p_value': pval
    })

# convert to dataframe
results_df = pd.DataFrame(results)

# BH correction
results_df['p_adj_BH'] = multipletests(results_df['p_value'], method='fdr_bh')[1]

# sort by adjusted p-value
results_df = results_df.sort_values('p_adj_BH')

print(results_df.round(3))
# Out:
#           sig1             sig2  odds_ratio  p_value  p_adj_BH
# 10  AR regulon    OVOL1 regulon       7.875    0.001     0.010
# 1   AR regulon    FOSL1 regulon       4.614    0.013     0.071
# 4   AR regulon    SOX15 regulon       3.704    0.029     0.106
# 3   AR regulon     ETS2 regulon       2.833    0.098     0.161
# 8   AR regulon      REL regulon       2.727    0.101     0.161
# 9   AR regulon  BHLHE41 regulon       2.660    0.102     0.161
# 0   AR regulon  BHLHE40 regulon       2.660    0.102     0.161
# 2   AR regulon     IRF6 regulon       2.361    0.170     0.234
# 7   AR regulon     SPIB regulon       2.051    0.271     0.331
# 5   AR regulon    NFKB2 regulon       1.674    0.415     0.456
# 6   AR regulon     RELB regulon       1.266    0.785     0.785

# %%
from itertools import combinations

import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu


# -----------------------------
# Settings
# -----------------------------
valid_trt = ["adt", "adt_apa"]
regress_out_rcb_volume = False
pct_var = "Epithelial cell pct"

tf1 = "AR"
tf2 = "FOSL1"

save_path = "/home/ak431480/notebooks/figures/ARNEO_regulons_boxplot.pdf"


# -----------------------------
# Data prep
# -----------------------------
df_all = (
    dat_treated_with_clinical.copy()
    .loc[lambda d: d["TRT_GROUP"].isin(valid_trt)]
    .loc[lambda d: d["ypT2"] == 0]
    .copy()
)

# optional minimum epithelial fraction filter
# df_all = df_all[df_all[pct_var] > 10.0].copy()

if regress_out_rcb_volume:
    regulon_cols = [c for c in df_all.columns if "regulon" in c]
    reg_df = df_all[regulon_cols + [pct_var]].copy()
    reg_df = regress_out_signature(reg_df, [pct_var])
    df_all.loc[:, reg_df.columns] = reg_df

# palette
base_pal = sns.color_palette("Set2")
trt_palette = {
    "adt": base_pal[2],
    "adt_apa": base_pal[1],
}

sns.set_theme(
    style="white",
    palette=[trt_palette["adt"], trt_palette["adt_apa"]],
    font_scale=0.55,
    rc={"xtick.bottom": True, "ytick.left": True},
)


# -----------------------------
# Plot specifications
# -----------------------------
plot_specs = [
    {
        "data": df_all,
        "sig": f"{tf1} regulon",
        "x": "TRT_GROUP",
        "hue": "TRT_GROUP",
        "title": f"{tf1} regulon",
        "order": ["adt", "adt_apa"],
        "palette": trt_palette,
    },
    {
        "data": df_all,
        "sig": f"{tf2} regulon",
        "x": "TRT_GROUP",
        "hue": "TRT_GROUP",
        "title": f"{tf2} regulon",
        "order": ["adt", "adt_apa"],
        "palette": trt_palette,
    },
    {
        "data": df_all[df_all["TRT_GROUP"] == "adt"].copy(),
        "sig": f"{tf1} regulon",
        "x": "BCR_3y",
        "hue": "TRT_GROUP",
        "title": f"{tf1} regulon",
        "order": None,
        "palette": {"adt": trt_palette["adt"]},
    },
    {
        "data": df_all[df_all["TRT_GROUP"] == "adt"].copy(),
        "sig": f"{tf2} regulon",
        "x": "BCR_3y",
        "hue": "TRT_GROUP",
        "title": f"{tf2} regulon",
        "order": None,
        "palette": {"adt": trt_palette["adt"]},
    },
    {
        "data": df_all[df_all["TRT_GROUP"] == "adt_apa"].copy(),
        "sig": f"{tf1} regulon",
        "x": "BCR_3y",
        "hue": "TRT_GROUP",
        "title": f"{tf1} regulon",
        "order": None,
        "palette": {"adt_apa": trt_palette["adt_apa"]},
    },
    {
        "data": df_all[df_all["TRT_GROUP"] == "adt_apa"].copy(),
        "sig": f"{tf2} regulon",
        "x": "BCR_3y",
        "hue": "TRT_GROUP",
        "title": f"{tf2} regulon",
        "order": None,
        "palette": {"adt_apa": trt_palette["adt_apa"]},
    },
]


# -----------------------------
# Helper
# -----------------------------
def get_pairwise_mwu_lines(data, x, y, order=None):
    if order is None:
        groups = data[x].dropna().unique().tolist()
    else:
        groups = [g for g in order if g in data[x].dropna().unique()]

    stat_lines = []
    for g1, g2 in combinations(groups, 2):
        d1 = data.loc[data[x] == g1, y].dropna()
        d2 = data.loc[data[x] == g2, y].dropna()
        if len(d1) > 0 and len(d2) > 0:
            _, pval = mannwhitneyu(d1, d2, alternative="two-sided")
            stat_lines.append(f"MWU p={pval:.3g}")
    return stat_lines


# -----------------------------
# Figure
# -----------------------------
fig, axes = plt.subplots(1, 6, figsize=(9, 2.6), sharey=True)

for ax, spec in zip(axes, plot_specs):
    plot_data = spec["data"].copy()

    sns.boxplot(
        data=plot_data,
        x=spec["x"],
        y=spec["sig"],
        order=spec["order"],
        color="whitesmoke",
        fliersize=0,
        ax=ax,
    )

    sns.swarmplot(
        data=plot_data,
        x=spec["x"],
        y=spec["sig"],
        hue=spec["hue"],
        order=spec["order"],
        palette=spec["palette"],
        s=4,
        edgecolor="black",
        linewidth=0.5,
        legend=False,
        ax=ax,
    )

    stat_lines = get_pairwise_mwu_lines(
        data=plot_data,
        x=spec["x"],
        y=spec["sig"],
        order=spec["order"],
    )

    title = spec["title"]
    if stat_lines:
        title += "\n" + "\n".join(stat_lines)

    ax.set_title(title, fontsize=6)
    #ax.set_xlabel("")
    ax.set_ylabel("")
    ax.spines[["top", "right"]].set_visible(False)
    ax.grid(axis="y")
    ax.set_ylim(-1.9, 2.2)
    ax.set_yticks([-1, 0, 1, 2])

plt.tight_layout()
plt.savefig(save_path, bbox_inches="tight")
plt.show()

# %%
# -----------------------------
# Data prep
# -----------------------------
valid_cat = ['adt', 'adt_apa']
plot_data = dat_treated_with_clinical.copy()
plot_data = plot_data[plot_data['TRT_GROUP'].isin(valid_cat)]
plot_data = plot_data[plot_data['ypT2'] == 0]

pal = sns.color_palette('Set2')
pal = sns.color_palette([pal[2], pal[1]])

sns.set_theme(
    style='white',
    palette=pal,
    font_scale=0.55,
    rc={'xtick.bottom': True, 'ytick.left': True}
)

df_all = plot_data.copy()
regress_out_rcb_volume = False
pct_var = 'Epithelial cell pct'

if regress_out_rcb_volume:
    df = df_all[[c for c in df_all.columns if 'regulon' in c] + [pct_var]]
    df = regress_out_signature(df, [pct_var])
    df_all[df.columns] = df

plot_data = df_all.copy()


# -----------------------------
# Figure
# -----------------------------
tf1 = 'Androgen signaling response'
tf2 = 'NF-κB survival signaling'

plots = [
    dict(sig=f'{tf1}',       x='TRT_GROUP', hue='TRT_GROUP', title=f'{tf1}'),
    dict(sig=f'{tf2}',       x='TRT_GROUP', hue='TRT_GROUP', title=f'{tf2}'),
    dict(sig='AR regulon',   x='BCR_3y',    hue='TRT_GROUP', title='AR regulon \n(split by BCR_3y)'),
    dict(sig='FOSL1 regulon',        x='BCR_3y',    hue='TRT_GROUP', title='FOSL1 \n(split by BCR_3y)'),
]

# Index where TF-only (adt_apa) plots begin
TF_START_IDX = plots.index(next(p for p in plots if p['sig'] == 'FOSL1 regulon'))

n_plots = len(plots)
n_cols  = 3
n_rows  = (n_plots + n_cols - 1) // n_cols  # ceil division

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4.5, 2.5 * n_rows), sharey=True)
axes_flat = axes.flatten()

# Hide any unused axes
for ax in axes_flat[n_plots:]:
    ax.set_visible(False)

# -----------------------------
# Plot loop
# -----------------------------
for i, (ax, p) in enumerate(zip(axes_flat, plots)):

    if i < TF_START_IDX:
        # First 3 plots: both groups, alternating palette logic as before
        if p == plots[2]:
            plot_data = df_all[df_all['TRT_GROUP'] == 'adt']
            sns.set_theme(
                style='white',
                palette=sns.color_palette([pal[0]]),
                font_scale=0.55,
                rc={'xtick.bottom': True, 'ytick.left': True}
            )
        else:
            plot_data = df_all.copy()
            sns.set_theme(
                style='white',
                palette=pal,
                font_scale=0.55,
                rc={'xtick.bottom': True, 'ytick.left': True}
            )
    else:
        # TF plots: adt_apa only
        plot_data = df_all[df_all['TRT_GROUP'] == 'adt_apa'].copy()
        sns.set_theme(
            style='white',
            palette=sns.color_palette([pal[1]]),
            font_scale=0.55,
            rc={'xtick.bottom': True, 'ytick.left': True}
        )

    sns.boxplot(
        data=plot_data,
        x=p['x'],
        y=p['sig'],
        color='whitesmoke',
        fliersize=0,
        ax=ax
    )

    sns.swarmplot(
        data=plot_data,
        x=p['x'],
        y=p['sig'],
        hue=p['hue'],
        s=4,
        edgecolor='black',
        linewidth=0.5,
        legend=False,
        ax=ax
    )

    # Mann–Whitney U (pairwise within x)
    groups = plot_data[p['x']].dropna().unique()
    mw_pvals = []
    for g1, g2 in combinations(groups, 2):
        d1 = plot_data[plot_data[p['x']] == g1][p['sig']].dropna()
        d2 = plot_data[plot_data[p['x']] == g2][p['sig']].dropna()
        if len(d1) > 0 and len(d2) > 0:
            _, pval = mannwhitneyu(d1, d2, alternative='two-sided')
            mw_pvals.append(f"{g1} vs {g2}: {pval:.4f}")

    ax.set_title(
        p['title'] + ("\n" + "\n".join(mw_pvals) if mw_pvals else ""),
        fontsize=6
    )

    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.spines[['top', 'right']].set_visible(False)
    ax.grid(axis='y')

    ax.set_ylim(-2.2, 2.2)
    ax.set_yticks([-2, -1, 0, 1, 2])

plt.tight_layout()
plt.savefig('/home/ak431480/notebooks/figures/ARNEO_regulons_boxplot.pdf')
plt.show()

# %%
meta = arneo_clinical[['Randomisation','BCR_3y','Time between RP and BCR','ypT2','ISUP biopsy']]
meta['BCR'] = meta['BCR_3y'].map({0:'No',1:'Yes'})
#meta.columns = ['Sample ID','event','time_to_bcr']
meta
# Out:
# /tmp/ipykernel_427263/498621105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta['BCR'] = meta['BCR_3y'].map({0:'No',1:'Yes'})
#                Randomisation  BCR_3y  Time between RP and BCR  ypT2  \
# PatientNumber
# ARN001                     0       0                       48     0
# ARN002                     1       0                       67     1
# ARN003                     1       0                       53     1
# ARN004                     0       0                       61     0
# ARN005                     1       0                       54     1
# ...                      ...     ...                      ...   ...
# ARN086                     1       0                       36     0
# ...

# %% [markdown]
# ## Splitting ATAC-samples by AR signaling & club-like/basal status

# %%
df.sort_values(sig2,ascending=False).index
low_ar_samples = ['ARN063','ARN032', 'ARN011', 'ARN056', 'ARN034','ARN026', 'ARN046']
high_ar_samples = ['ARN065', 'ARN001', 'ARN069','ARN087','ARN029','ARN060','ARN066']

df['ar_signaling_status'] = np.nan
df.loc[low_ar_samples,'ar_signaling_status'] = 'low'
df.loc[high_ar_samples,'ar_signaling_status'] = 'high'
# Out:
# /tmp/ipykernel_427263/3505926628.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'low' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[low_ar_samples,'ar_signaling_status'] = 'low'

# %%
sns.swarmplot(df,
    x = 'ar_signaling_status',
    y = 'FOSL1 regulon',

)
# Out:
# <Axes: xlabel='ar_signaling_status', ylabel='FOSL1 regulon'>

# %% [markdown]
# ## Labrecque et al. mCRPC bulk data

# %%
metastasis_mapping = {
    #     
    "CRPC lung metastasis": "lung metastasis",
    
    #
    "CRPC liver metastasis": "liver metastasis",
 
    # Lymph node metastasis
    "CRPC lymph node (LN) metastasis": "lymph node metastasis",

    # Bone metastasis
    "CRPC bone metastasis": "bone metastasis",

    # Soft tissue metastasis
    "CRPC adrenal metastasis": "soft tissue metastasis",
    "CRPC retroperitoneal metastasis": "soft tissue metastasis",
    "CRPC diaphram metastasis": "soft tissue metastasis",
    "CRPC renal metastasis": "soft tissue metastasis",
    "CRPC bladder metastasis": "soft tissue metastasis",
    "CRPC pelvic mass metastasis": "soft tissue metastasis",
    "CRPC pleural metastasis": "soft tissue metastasis",
    "CRPC left posterior metastasis": "soft tissue metastasis",
    "CRPC spleen metastasis": "soft tissue metastasis",
    "CRPC periaortic metastasis": "soft tissue metastasis",
    "CRPC periaortic diaphragm metastasis": "soft tissue metastasis",
    "CRPC parietal diaphragm metastasis": "soft tissue metastasis",
    "CRPC tail of pancreas metastasis": "soft tissue metastasis",
    "CRPC pancreas metastasis": "soft tissue metastasis",
    "CRPC perirectal omental metastasis": "soft tissue metastasis",
    "CRPC pelvic peritoneal metastasis": "soft tissue metastasis",

}

# Match gene names to those in signatures
gene_alias_dict = {
    'ACP3' : 'ACPP',
    'CCN1' : 'CYR61',
    'SHLD2' : 'FAM35A',
    'TENT5C': 'FAM46C',
    'TAFA5' : 'FAM19A5',
    'GET3' : 'ASNA1',
}

# %%
# Download data and format metadata
dat = pd.read_csv('./data/labrecque_2019/GSE126078_norm_counts_TPM_GRCh38.p13_NCBI.tsv',sep='\t',index_col=0) # NCBI-generated TPM matrix from https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE126078

# Replace Entrez IDs with gene symbols
gene_annot = pd.read_csv('./data/labrecque_2019/Human.GRCh38.p13.annot.tsv',sep='\t')
gene_mapping_dict = gene_annot.set_index('GeneID')['Symbol'].to_dict()
dat.index = dat.index.map(gene_mapping_dict)

# Normalize by protein coding
protein_coding_genes = list(set(gene_annot[gene_annot['GeneType'] == 'protein-coding']['Symbol']))
dat = dat[dat.index.isin(protein_coding_genes)]
dat = dat.rename(index=gene_alias_dict)

meta = pd.read_csv('./data/labrecque_2019/GSE126078_series_matrix.txt',sep='\t',skiprows=51,index_col=0)
# Extract relevant columns
meta = meta.T[['!Sample_geo_accession','!Sample_characteristics_ch1','!Sample_source_name_ch1']]

# Drop unused columns
meta = pd.DataFrame(meta.iloc[:,[0,4,5,7]])
column_names = ['GEO_ID','patient','molecular_phenotype','metastatic_site']
meta.columns = column_names


# Map the sample names onto columns
geo_to_sample_dict = meta.reset_index().set_index('GEO_ID')['index'].to_dict()
dat.columns = dat.columns.map(geo_to_sample_dict)

CRPC_only = True #### Adjust accordingly
if CRPC_only:
    meta = meta[meta.index.str.contains('CRPC')]
    dat = dat[meta.index.tolist()]
    meta['molecular_phenotype'] = pd.Categorical([s.split(': ')[1] for s in meta['molecular_phenotype']],categories=['ARpos_NEneg','ARpos_NEpos','ARneg_NEpos','ARlow_NEneg','ARneg_NEneg'])

# Drop the 'patient: ' prefix in the patient column
meta['patient'] = [p.split(' ')[1] for p in meta['patient']]

meta_index = meta.index.copy()
# Add the mutation metadata
mutation_metadata = pd.read_excel('/home/ak431480/labrecque_2019_mutation_data.xlsx')
cna_categories = ['amplification', 'cn_gain', 'cnv', 'none', 'monoallelic_loss','biallelic_loss','missing']
for c in mutation_metadata:
    if '_STATUS' in c:
        mutation_metadata[c] = pd.Categorical(mutation_metadata[c],categories = cna_categories)
        mutation_metadata[c] = mutation_metadata[c].cat.remove_unused_categories()

meta = pd.merge(meta,mutation_metadata,left_on='patient',right_on='patient',how='left')
meta[mutation_metadata.columns[1:]] = meta[mutation_metadata.columns[1:]].fillna('missing')

meta.index = meta_index.copy()

tpm = dat.copy()

# Remove overlaps
gene_modules_dict_mod = gene_modules_dict.copy()

gsva_res = gp.gsva(data=tpm,gene_sets=gene_modules_dict_mod,outdir=None,min_size=0,max_size=100000)
gsva_res_df = gsva_res.res2d.pivot(index='Name', columns='Term', values='ES').reset_index(names='Sample Identifier')

gsva_res_meta = pd.merge(meta,gsva_res_df, right_on='Sample Identifier',left_index=True)

gsva_res_meta['metastatic_site_simple'] = pd.Categorical(gsva_res_meta['metastatic_site'].map(metastasis_mapping),categories=['lung metastasis','liver metastasis','lymph node metastasis','bone metastasis','soft tissue metastasis',])
# Out:
# /tmp/ipykernel_427263/4182164811.py:5: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   gene_annot = pd.read_csv('./data/labrecque_2019/Human.GRCh38.p13.annot.tsv',sep='\t')

# %%
def p_to_star(p):
    if p < 1e-3:
        return '***'
    elif p < 1e-2:
        return '**'
    elif p < 0.05:
        return '*'
    else:
        return 'ns'

plot_df = gsva_res_meta[~((gsva_res_meta == 'missing').any(axis=1))].reset_index(drop=True)


sig = 'FOSL1 regulon'
var = 'PTEN_STATUS'
alt_type = 'del' # 'gain', 'del'


if alt_type == 'gain':
    pal = 'Reds'
    cn_categories = ['none','cn_gain','amplification']
else:
    pal = 'Blues'
    cn_categories = ['none','monoallelic_loss','biallelic_loss']


sns.set_theme(style='white', 
    #palette='Blues',
    palette=pal,
    font_scale=0.55, rc={
    'xtick.bottom': True,
    'ytick.left': True
})


plot_df[var] = pd.Categorical(plot_df[var])

# Only keep categories if they're present in 10% or more samples
val_counts = plot_df[var].value_counts()
valid_categories = val_counts[val_counts >= len(plot_df)*0.1].index.tolist()
plot_df = plot_df[plot_df[var].isin(valid_categories)]

plot_df[var] = plot_df[var].cat.remove_unused_categories()
plot_df[var] = plot_df[var].cat.set_categories(cn_categories)

stat, p_val = kruskal(*plot_df[[var,sig]].groupby(var)[sig].apply(list))

#fig, ax = plt.subplots(figsize=(1.8,2.5))
fig, ax = plt.subplots(figsize=(3,4))

sns.swarmplot(plot_df,
              x = var,
              y = sig,
              hue = var,
              edgecolor='black',
              linewidth = 0.5,
              s = 6,
              legend = False,
              ax = ax
              )


sns.boxplot(data=plot_df,
            x=var,
            y=sig,
            color='whitesmoke',
            showfliers=False,
            linewidth=1,
            ax=ax)

ax.spines[['right','top']].set_visible(False)

ax.set_yticks([-0.6,-0.3,0,0.3,0.6])
#ax.set_ylim(-0.65,0.85)
ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)
#ax.set_xticklabels([])
plt.grid(axis='y')

# category order & x positions
cats = plot_df[var].cat.categories.tolist()
x_pos = {c: i for i, c in enumerate(cats)}

# base height for annotations
y_max = plot_df[sig].max()
y_min = plot_df[sig].min()
y_range = y_max - y_min

h = 0.05 * y_range      # vertical spacing between bars
y = y_max + 0.05*y_range

for grp1, grp2 in combinations(cats, 2):
    data1 = plot_df.loc[plot_df[var] == grp1, sig]
    data2 = plot_df.loc[plot_df[var] == grp2, sig]

    stat, pval = ranksums(data1, data2)
    star = p_to_star(pval)

    if star == 'ns':
        continue  # skip non-significant if you want cleaner plots

    x1, x2 = x_pos[grp1], x_pos[grp2]

    # draw bar
    ax.plot([x1, x1, x2, x2],
            [y, y+h, y+h, y],
            lw=1.0, c='black')

    # draw stars
    ax.text((x1 + x2)/2, y + h,
            star,
            ha='center', va='bottom',
            weight='bold',
            fontsize=9)

    y += h * 1.5  # increment for next comparison

plt.tight_layout()
plt.savefig(f'/home/ak431480/plots/Labracque_et_al_{sig}_by_{var}_boxplot.pdf')
plt.show()
# Out:
# /tmp/ipykernel_427263/3749860632.py:46: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat, p_val = kruskal(*plot_df[[var,sig]].groupby(var)[sig].apply(list))
# /tmp/ipykernel_427263/3749860632.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)

# %% [markdown]
# ### Molecular phenotype – gene signature activity

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='white', palette='Dark2', font_scale=0.7, rc={
    'xtick.bottom': True,
    'ytick.left': True
})

var = 'molecular_phenotype'
sigs = [
    'AR regulon',
    'NKX3-1 regulon',
    'ASCL1 regulon',
    'SOX4 regulon',
    'KLF5 regulon',
    'FOSL1 regulon',
    'Basal',
    'Duct luminal'
    #'IRF1 regulon',
    #'GATA3 regulon'
]

n_cols = 4
n_rows = math.ceil(len(sigs) / n_cols)

fig, axes = plt.subplots(
    n_rows,
    n_cols,
    figsize=(n_cols * 3, n_rows * 4),
    squeeze=False
)

order = list(gsva_res_meta[var].cat.categories)

for ax, sig in zip(axes.flat, sigs):

    sns.stripplot(
        data=gsva_res_meta,
        x=var,
        y=sig,
        hue=var,
        order=order,
        edgecolor='black',
        linewidth=0.5,
        s=4,
        legend=False,
        ax=ax
    )

    sns.boxplot(
        data=gsva_res_meta,
        x=var,
        y=sig,
        order=order,
        color='whitesmoke',
        showfliers=False,
        linewidth=1,
        ax=ax
    )

    ax.spines[['right', 'top']].set_visible(False)
    ax.set_title(sig, fontsize=8)

    ax.set_yticks([-0.6, -0.3, 0, 0.3, 0.6])
    ax.set_ylim(-0.65, 0.8)
    ax.set_xlabel('')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)
    ax.grid(axis='y')

# hide unused panels
for ax in axes.flat[len(sigs):]:
    ax.axis('off')

plt.tight_layout()
plt.savefig('/home/ak431480/plots/Labracque_et_al_GSVA_scores_by_molecular_phenotype.pdf')
plt.show()
# Out:
# /tmp/ipykernel_427263/3687629574.py:68: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)
# /tmp/ipykernel_427263/3687629574.py:68: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)
# /tmp/ipykernel_427263/3687629574.py:68: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)
# /tmp/ipykernel_427263/3687629574.py:68: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(
    style='white',
    palette='Dark2',
    font_scale=1.0,
    rc={
        'xtick.bottom': True,
        'ytick.left': True,
        'axes.titlesize': 6,
        'axes.labelsize': 6,
        'xtick.labelsize': 6,
        'ytick.labelsize': 6,
    }
)

var = 'molecular_phenotype'
sig = 'FOSL1 regulon'
order = list(gsva_res_meta[var].cat.categories)

fig, ax = plt.subplots(figsize=(2.7, 3))

sns.stripplot(
    data=gsva_res_meta,
    x=var,
    y=sig,
    hue=var,
    order=order,
    edgecolor='black',
    linewidth=0.5,
    s=5,
    legend=False,
    ax=ax
)

sns.boxplot(
    data=gsva_res_meta,
    x=var,
    y=sig,
    order=order,
    color='whitesmoke',
    showfliers=False,
    linewidth=1,
    ax=ax
)

ax.spines[['right', 'top']].set_visible(False)
#ax.set_title('FOSL1 regulon', fontsize=6)
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_yticks([-0.6, -0.3, 0, 0.3, 0.6])
ax.set_ylim(-0.65, 0.8)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=-30)
ax.set_xticklabels([])
ax.grid(axis='y')

plt.tight_layout()
plt.savefig(
    '/home/ak431480/plots/Labracque_et_al_FOSL1_GSVA_by_molecular_phenotype.pdf',
    dpi=300
)
plt.show()

# %%
from itertools import combinations
from scipy.stats import ranksums

def p_to_stars(p):
    if p < 1e-4:
        return "****"
    elif p < 1e-3:
        return "***"
    elif p < 1e-2:
        return "**"
    elif p < 0.05:
        return "*"
    else:
        return "ns"

var = 'molecular_phenotype'
sig = 'FOSL1 regulon'
order = list(gsva_res_meta[var].cat.categories)

print(f"Pairwise Wilcoxon rank-sum tests for {sig}\n")

for g1, g2 in combinations(order, 2):
    x1 = gsva_res_meta.loc[gsva_res_meta[var] == g1, sig].dropna()
    x2 = gsva_res_meta.loc[gsva_res_meta[var] == g2, sig].dropna()

    stat, p = ranksums(x1, x2)
    stars = p_to_stars(p)

    print(f"{g1} vs {g2}: p = {p:.3e}  {stars}")
# Out:
# Pairwise Wilcoxon rank-sum tests for FOSL1 regulon
#
# ARpos_NEneg vs ARpos_NEpos: p = 3.908e-01  ns
# ARpos_NEneg vs ARneg_NEpos: p = 1.794e-01  ns
# ARpos_NEneg vs ARlow_NEneg: p = 2.180e-03  **
# ARpos_NEneg vs ARneg_NEneg: p = 5.705e-04  ***
# ARpos_NEpos vs ARneg_NEpos: p = 8.880e-01  ns
# ARpos_NEpos vs ARlow_NEneg: p = 1.617e-03  **
# ARpos_NEpos vs ARneg_NEneg: p = 2.249e-03  **
# ARneg_NEpos vs ARlow_NEneg: p = 4.465e-04  ***
# ARneg_NEpos vs ARneg_NEneg: p = 1.381e-03  **
# ARlow_NEneg vs ARneg_NEneg: p = 1.489e-01  ns

# %% [markdown]
# ### Differential gene expression analysis

# %%
neg_samples = meta[meta['molecular_phenotype'].isin(['ARlow_NEneg','ARneg_NEneg'])].index.tolist()
other_samples = meta[meta['molecular_phenotype'].isin(['ARpos_NEneg','ARpos_NEpos','ARpos_NEpos'])].index.tolist()
#hvgs = tpm.var(axis=1).sort_values(ascending=False)[:2000].index.tolist()
hvgs = tpm.index.tolist()

# Extract sub-dataframes once
df = tpm.loc[hvgs]
neg_df = df[neg_samples]
other_df = df[other_samples]

# Precompute medians
neg_medians = neg_df.median(axis=1) + 1e-4
other_medians = other_df.median(axis=1) + 1e-4

# Log2 fold-change (vectorized)
log2fc = np.log2(neg_medians / other_medians)

# Compute p-values (still per gene, ranksums has no vectorized API)
pvals = [
    ranksums(neg_df.loc[g], other_df.loc[g]).pvalue
    for g in hvgs
]

# Build results dataframe
deg_results_df = pd.DataFrame({
    "gene": hvgs,
    "log2fc": log2fc.values,
    "pval": pvals
})

# FDR correction
deg_results_df["fdr"] = multipletests(deg_results_df["pval"], method="fdr_bh")[1]
deg_results_df = deg_results_df.sort_values('fdr',ascending=True).reset_index(drop=True)

upregulated_genes_df = deg_results_df[((deg_results_df['log2fc'] >=1) & (deg_results_df['fdr'] < 0.05))]

# %%
#upregulated_genes_df[upregulated_genes_df['gene'].str.contains('PIGR')]
upregulated_genes_df[upregulated_genes_df['gene'].isin(gene_modules['FOSL1 regulon'].tolist())]

[print(g) for g in upregulated_genes_df[upregulated_genes_df['gene'].isin(gene_modules['FOSL1 regulon'].tolist())]['gene']]
# Out:
# CD55
# DKK1
# PIM1
# AREG
# EPHA2
# KRT17
# ARID5A
# [None, None, None, None, None, None, None]

# %% [markdown]
# ### Plot DNPC upregulated genes in ARNEO correlation plot

# %%
treated_samples = metadata[metadata['TRT_GROUP_SIMPLE'] == 'neoadjuvant-treated'].index.tolist()
arneo_rnaseq_data = rnaseq_data.loc[rnaseq_data.index.isin(tpm.index.tolist()),treated_samples]
arneo_scoring_data_subset = arneo_scoring_data.loc[treated_samples]

results = []
sig = 'FOSL1 regulon'

valid_genes = [g for g in upregulated_genes_df['gene'].tolist() if g in arneo_rnaseq_data.index.tolist()]

for g in valid_genes:
    stat, pval = spearmanr(arneo_rnaseq_data.loc[g], arneo_scoring_data_subset[sig])
    results.append({
        'Gene': g,
        'SpearmanR': stat,
        'P-value': pval
    })

results_df = pd.DataFrame(results)
results_df = results_df.dropna()
results_df['FDR'] = multipletests(results_df['P-value'], method='fdr_bh')[1]
results_df['FDR_binary'] = (results_df['FDR'] < 0.05).astype(int)
results_df['-log10FDR'] = -np.log10(results_df['FDR'])

results_df = results_df.sort_values('SpearmanR',ascending=False).reset_index(drop=True)

results_df = results_df[~(results_df['Gene'].isin(gene_modules_dict[sig]))].reset_index(drop=True)
# Out:
# /tmp/ipykernel_427263/3957243059.py:11: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   stat, pval = spearmanr(arneo_rnaseq_data.loc[g], arneo_scoring_data_subset[sig])

# %%
#genes = gene_modules_dict['JAK_STAT_FGFR']
inflammation_genes = [
    "CXCL8",
    "IL6",
    "CXCL1",
    "TNFRSF12A",
    "IL1R1",
    "CD40",
    "TNFSF12",
    "TNFRSF1A",
    "TNFRSF1B",
    #"ICAM1",
    #"SOCS3",
    "PLAUR",
    "PIGR",
    'CP',
    'LTF',
    "FOSL1",
    "KLF5",
]

top_genes = results_df[(results_df['FDR']<0.05) & (results_df['Gene'].isin(inflammation_genes))]

sns.set_theme(style='white', palette=sns.color_palette(['lightgray', 'firebrick']), font_scale=0.55,
              rc={'xtick.bottom': True, 'ytick.left': True})

fig, ax = plt.subplots(figsize=(1.5, 2.5))

sns.scatterplot(data=results_df,
                x='SpearmanR',
                y='-log10FDR',
                hue='FDR_binary',
                edgecolor='black',
                linewidth=0,
                s=12,
                legend=None,
                ax=ax)

from adjustText import adjust_text

texts = []
for _, row in top_genes.iterrows():
    texts.append(ax.text(row['SpearmanR'], row['-log10FDR'], row['Gene'], fontsize=8, ha='right'))

ax.set_yticks([0,3,6,9])
ax.set_ylim([-0.5,9.5])
ax.set_xticks([-0.4,0,0.4,0.8])
ax.set_xlim(-0.55,0.85)
adjust_text(texts, ax=ax, arrowprops=dict(arrowstyle='-', color='gray', lw=0.5))


ax.spines[['top', 'right']].set_visible(False)
plt.grid(axis='y')

plt.tight_layout()

plt.savefig('/home/ak431480/plots/ARNEO_correlating_chemokines.pdf')
plt.show()

# %%
results_df[:30]
# Out:
#          Gene  SpearmanR       P-value           FDR  FDR_binary  -log10FDR
# 0       CXCL8   0.631435  4.232133e-11  5.603344e-08           1   7.251553
# 1       RGS16   0.620783  1.104751e-10  7.313450e-08           1   7.135878
# 2       SOCS3   0.598570  7.303986e-10  2.610068e-07           1   6.583348
# 3     SDR16C5   0.597050  8.268100e-10  2.610068e-07           1   6.583348
# 4      S100A2   0.588334  1.662844e-09  3.620509e-07           1   6.441230
# 5       ICAM1   0.582246  2.676368e-09  4.337415e-07           1   6.362769
# 6     CYP24A1   0.580992  2.948394e-09  4.337415e-07           1   6.362769
# 7       PLAUR   0.575935  4.338779e-09  5.557649e-07           1   6.255109
# 8      FGFBP1   0.572304  5.702801e-09  6.292091e-07           1   6.201205
# 9         IL6   0.563891  1.060896e-08  1.080481e-06           1   5.966383
# 10      CXCL1   0.552403  2.409385e-08  2.278589e-06           1   5.642334
# ...

# %%
#results_df[results_df['Gene'].str.contains('TNF')]
results_df[results_df['Gene'].isin(inflammation_genes)]
#results_df[-5:]
# Out:
#           Gene  SpearmanR       P-value           FDR  FDR_binary  -log10FDR
# 0        CXCL8   0.631435  4.232133e-11  5.603344e-08           1   7.251553
# 7        PLAUR   0.575935  4.338779e-09  5.557649e-07           1   6.255109
# 9          IL6   0.563891  1.060896e-08  1.080481e-06           1   5.966383
# 10       CXCL1   0.552403  2.409385e-08  2.278589e-06           1   5.642334
# 11       FOSL1   0.542452  4.784329e-08  4.222968e-06           1   5.374382
# 21   TNFRSF12A   0.499042  7.463232e-07  3.529043e-05           1   4.452343
# 53          CP   0.445127  1.390297e-05  3.010430e-04           1   3.521372
# 184       PIGR   0.335106  1.415664e-03  9.711601e-03           1   2.012709
# 202        LTF   0.321986  2.219160e-03  1.392497e-02           1   1.856206
# 235   TNFRSF1B   0.304468  3.924910e-03  2.129746e-02           1   1.671672
# 316       KLF5   0.272498  1.021353e-02  4.135386e-02           1   1.383484

# %% [markdown]
# ### Correlation plot

# %%
sns.set_theme(style='white', palette='Dark2', font_scale=0.55, rc={
    'xtick.bottom': True,
    'ytick.left': True
})

sig1 = 'AR regulon'
sig2 = 'FOSL1 regulon'

df = pd.merge(meta,gsva_res_df, right_on='Sample Identifier',left_index=True)

df[sig1] = df[sig1].astype('float64')
df[sig2] = df[sig2].astype('float64')

fig, ax = plt.subplots(figsize=(2,2))

stat, pval = spearmanr(df[sig1],df[sig2])

sns.regplot(df,
                x = sig1,
                y= sig2,
                scatter=False,
                color='black',
                ax=ax
                )

sns.scatterplot(df,
                x = sig1,
                y= sig2,
                edgecolor='black',
                hue = 'molecular_phenotype',
                linewidth=1,
                s = 10,
                legend=None,
                ax=ax
                )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([-0.6,-0.3,0,0.3,0.6])
ax.set_yticks([-0.6,-0.3,0,0.3,0.6])

ax.set_title(f'Spearman r: {stat:.2f}\np-value: {pval:.1e}')

plt.tight_layout()
plt.savefig('./plots/tmp/regplot.pdf')

plt.show()

# %%
sns.set_theme(style='white', palette='Accent', font_scale=0.55, rc={
    'xtick.bottom': True,
    'ytick.left': True
})

sig1 = 'FOSL1 regulon'#'HALLMARK_IL6_JAK_STAT3_SIGNALING'
sig2 = 'HALLMARK_TNFA_SIGNALING_VIA_NFKB'#'HALLMARK_IL6_JAK_STAT3_SIGNALING'

# --- 2x2 layout (4 inches x 4 inches total) ---
fig, axs = plt.subplots(2, 2, figsize=(2.7, 2.5), sharex=True, sharey=True)
axs = axs.flatten()

# ----------------------------
# Panels A–C: By TRT_GROUP
# ----------------------------
groups = ['treatment-naive', 'adt', 'adt_apa']
for i, grp in enumerate(groups):
    ax = axs[i]
    df_sub = arneo_scoring_data[arneo_scoring_data['TRT_GROUP'] == grp].copy()
    stat, pval = spearmanr(df_sub[sig1], df_sub[sig2])

    sns.regplot(df_sub,
                x=sig1, y=sig2,
                scatter=False,
                color='black',
                ax=ax)

    sns.scatterplot(df_sub,
                    x=sig1, y=sig2,
                    edgecolor='black',
                    hue='TRT_GROUP',
                    linewidth=0.5,
                    s=10,
                    legend=None,
                    ax=ax)

    ax.set_xticks([-0.8, -0.4, 0, 0.4, 0.8])
    ax.set_yticks([-0.8, -0.4, 0, 0.4, 0.8])
    ax.text(s=f'r = {stat:.2f}\np = {pval:.1e}', x=-0.25, y=0.5, size=5)
    #ax.set_title(grp, fontsize=6)
    ax.spines[['top','right']].set_visible(False)
# -------------------
# Panel D: All samples
# -------------------

sns.set_theme(style='white', palette='Dark2', font_scale=0.55, rc={
    'xtick.bottom': True,
    'ytick.left': True
})


ax = axs[3]
df = pd.merge(meta, gsva_res_df, right_on='Sample Identifier', left_index=True)
df[sig1] = df[sig1].astype('float64')
df[sig2] = df[sig2].astype('float64')

stat, pval = spearmanr(df[sig1], df[sig2])

sns.regplot(df,
            x=sig1, y=sig2,
            scatter=False,
            color='black',
            ax=ax)

sns.scatterplot(df,
                x=sig1, y=sig2,
                edgecolor='black',
                hue='molecular_phenotype',
                #color = 'orange',
                linewidth=0.5,
                s=10,
                legend=None,
                ax=ax)

ax.spines[['top','right']].set_visible(False)
ax.set_xticks([-0.6, -0.3, 0, 0.3, 0.6])
ax.set_yticks([-0.6, -0.3, 0, 0.3, 0.6])
ax.text(s=f'r = {stat:.2f}\np = {pval:.1e}', x=-0.25, y=0.5, size=5)
ax.set_title('')

# -------------------
# Axes labels
# -------------------
for i, ax in enumerate(axs):
    if i % 2 == 0:  # left column
        ax.set_ylabel(sig2, fontsize=6)
    else:
        ax.set_ylabel("")
    if i >= 2:      # bottom row
        ax.set_xlabel(sig1, fontsize=6)
    else:
        ax.set_xlabel("")

plt.tight_layout()
plt.savefig('/home/ak431480/plots/combined_2x2_regplots_ordered.pdf')
plt.show()

# %%
np.intersect1d(gene_modules_dict[sig1],gene_modules_dict[sig2])
# Out:
# array(['AREG', 'CDKN1A', 'DUSP5', 'PLAU'], dtype='<U8')

# %%
sns.set_theme(style='white', palette = 'Accent' , font_scale=0.55,rc={
    'xtick.bottom': True,
    'ytick.left': True})

sig1 = 'TISS'#'Basal_B1_Basal-ESR1'#'d2_dLum-KRT4' #'B1_Basal-ESR1'#
sig2 = 'HALLMARK_TNFA_SIGNALING_VIA_NFKB'#'HALLMARK_TNFA_SIGNALING_VIA_NFKB'#'Ductal luminal'#'d1_dLum-Club'#'IL1B MDSCs'#'d1_dLum-Club'

fig,axs = plt.subplots(1,3,figsize=(6,2),sharey=True,sharex=True)

for i,grp in enumerate(['treatment-naive','adt','adt_apa']):

    ax = axs[i]
    df = arneo_scoring_data[arneo_scoring_data['TRT_GROUP'] == grp].copy()

    stat, pval = spearmanr(df[sig1],df[sig2])

    sns.regplot(df,
                    x = sig1,
                    y= sig2,
                    scatter=False,
                    color='black',
                    ax=ax
                    )

    sns.scatterplot(df,
                    x = sig1,
                    y= sig2,
                    edgecolor='black',
                    hue = 'TRT_GROUP',
                    linewidth=0.5,
                    s = 15,
                    legend=None,
                    ax=ax
                    )

    ax.set_xticks([-0.8,-0.4,0,0.4,0.8])
    ax.set_yticks([-0.8,-0.4,0,0.4,0.8])
    ax.text(s=f'r = {stat:.2f}\np = {pval:.1e}', x = -0.25,y = 0.5, size=6)
    ax.spines[['top','right']].set_visible(False)
    ax.set_ylabel('HALLMARK_TNFa')

plt.tight_layout()
plt.savefig('/home/ak431480/plots/aa_regplot_signatures_arneo.pdf')
plt.show()
